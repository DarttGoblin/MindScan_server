# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import tensorflow.keras.backend as K
from tensorflow.keras.metrics import F1Score
from tqdm import tqdm

BATCH_SIZE = 32
EPOCHS = 10
DATA_DIR = 'brain_mri_dataset'

# %%
images = []
labels = []

abnormal_classes = ['glioma', 'meningioma', 'pituitary']

# Load abnormal images and undersample each class to 667
for idx, label in enumerate(abnormal_classes):
    folder = os.path.join(DATA_DIR, label)

    img_names = [f for f in os.listdir(folder) if f.lower().endswith('.jpg')]
    img_names = shuffle(img_names, random_state=42)[:667]

    for img_name in tqdm(img_names, desc=f'Loading {label}'):
        img_path = os.path.join(folder, img_name)
        img = load_img(img_path, target_size=(224,224))
        img_array = img_to_array(img) / 255.0
        images.append(img_array)
        labels.append(idx)  # label index corresponds to class

# Convert to numpy arrays and one-hot encode labels
images = np.array(images)
labels = tf.keras.utils.to_categorical(labels, num_classes=len(abnormal_classes))

# Show example images from each class
for idx, label in enumerate(abnormal_classes):
    sample_img = images[labels[:, idx] == 1][0]
    plt.imshow(sample_img)
    plt.title(label)
    plt.axis("off")
    plt.show()
# Out:
# Loading glioma: 100%|███████████████████████████████████████████████████████████████| 667/667 [00:01<00:00, 340.70it/s]
# Loading meningioma: 100%|███████████████████████████████████████████████████████████| 667/667 [00:01<00:00, 374.92it/s]
# Loading pituitary: 100%|████████████████████████████████████████████████████████████| 667/667 [00:01<00:00, 348.21it/s]

# %%
img_input = layers.Input(shape=(224,224,3))
base = MobileNetV2(include_top=False, weights='imagenet', input_tensor=img_input)
base.trainable = False

x = layers.GlobalAveragePooling2D()(base.output)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.3)(x)
output = layers.Dense(len(abnormal_classes), activation='softmax')(x)

model = Model(inputs=img_input, outputs=output)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.F1Score(average='macro')]
)

X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state=42)

model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18496\2260958424.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = MobileNetV2(include_top=False, weights='imagenet', input_tensor=img_input)
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 474ms/step - accuracy: 0.7088 - f1_score: 0.7070 - loss: 0.6788 - precision: 0.7522 - recall: 0.6506 - val_accuracy: 0.7905 - val_f1_score: 0.7877 - val_loss: 0.5135 - val_precision: 0.8209 - val_recall: 0.7656
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - accuracy: 0.8331 - f1_score: 0.8326 - loss: 0.4188 - precision: 0.8474 - recall: 0.8156 - val_accuracy: 0.8180 - val_f1_score: 0.8218 - val_loss: 0.4558 - val_precision: 0.8244 - val_recall: 0.8080
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - accuracy: 0.8712 - f1_score: 0.8709 - loss: 0.3318 - precision: 0.8850 - recall: 0.8562 - val_accuracy: 0.8479 - val_f1_score: 0.8470 - val_loss: 0.3805 - val_precision: 0.8593 - val_recall: 0.8379
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.8831 - f1_score: 0.8827 - loss: 0.2955 - precision: 0.8923 - recall: 0.8750 - val_accuracy: 0.8479 - val_f1_score: 0.8487 - val_loss: 0.3598 - val_precision: 0.8575 - val_recall: 0.8404
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 0.9062 - f1_score: 0.9059 - loss: 0.2587 - precision: 0.9128 - recall: 0.8963 - val_accuracy: 0.8628 - val_f1_score: 0.8623 - val_loss: 0.3444 - val_precision: 0.8645 - val_recall: 0.8429
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 0.9194 - f1_score: 0.9191 - loss: 0.2193 - precision: 0.9256 - recall: 0.9100 - val_accuracy: 0.8579 - val_f1_score: 0.8582 - val_loss: 0.3537 - val_precision: 0.8680 - val_recall: 0.8529
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - accuracy: 0.9262 - f1_score: 0.9261 - loss: 0.2051 - precision: 0.9313 - recall: 0.9231 - val_accuracy: 0.8579 - val_f1_score: 0.8571 - val_loss: 0.3471 - val_precision: 0.8629 - val_recall: 0.8479
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - accuracy: 0.9306 - f1_score: 0.9305 - loss: 0.1838 - precision: 0.9357 - recall: 0.9275 - val_accuracy: 0.8554 - val_f1_score: 0.8572 - val_loss: 0.3571 - val_precision: 0.8539 - val_recall: 0.8454
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - accuracy: 0.9344 - f1_score: 0.9343 - loss: 0.1587 - precision: 0.9389 - recall: 0.9312 - val_accuracy: 0.8628 - val_f1_score: 0.8613 - val_loss: 0.3329 - val_precision: 0.8709 - val_recall: 0.8579
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.9538 - f1_score: 0.9537 - loss: 0.1346 - precision: 0.9554 - recall: 0.9506 - val_accuracy: 0.8728 - val_f1_score: 0.8739 - val_loss: 0.3215 - val_precision: 0.8769 - val_recall: 0.8703

# %%
# Keras and h5 format
model.save('downloaded_models/mobilenetv2/multi_classifier/multi_brain_mri_model.h5')
model.save('downloaded_models/mobilenetv2/multi_classifier/multi_brain_mri_model.keras')

# TensorFlow SavedModel format (folder)
model.export('downloaded_models/mobilenetv2/multi_classifier/multi_brain_mri_model_folder')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# INFO:tensorflow:Assets written to: downloaded_models/mobilenetv2/multi_classifier/multi_brain_mri_model_folder\assets
# INFO:tensorflow:Assets written to: downloaded_models/mobilenetv2/multi_classifier/multi_brain_mri_model_folder\assets
# Saved artifact at 'downloaded_models/mobilenetv2/multi_classifier/multi_brain_mri_model_folder'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2403536386576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952281552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952281744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952281168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403536386768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952282704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952282512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952284240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952286928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952283856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952288272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403536387344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403536387728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952286160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403536386384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952288848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952289808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952289232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952289424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952289616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952288080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952290768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952291152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952291344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952290384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952290960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952291920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952292304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952292496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952291536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952292112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952293072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952292688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952292880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952290000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952294032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952293648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952293840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952290192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952294992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952294416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952294608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952294224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952295760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952295184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952293264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952295376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952295568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952294800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2403952291728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006798096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006799248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006799056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006798672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006799824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006798288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006799440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006799632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006797904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006800784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006800208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006800400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006800592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006798480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006801744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006801168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006801360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006801552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006798864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006802704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006802128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006802320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006802512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006800016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006803664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006803088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006803280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006803472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006800976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006804624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006804048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006804240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006804432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006805584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006805008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006805200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006805392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006802896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006806544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006805968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006806160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006806352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006803856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006807504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006806928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006807120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006807312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006804816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006808464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006807888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006808080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006808272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006805776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006809424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006808848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006809040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006809232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006806736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006810384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006809808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006810000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006810192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006807696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006811344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006810768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006810960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006811152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006808656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006812304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006811728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006811920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006812112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006809616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006813264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006812688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006812880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006812496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006814032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006813456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006811536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006813648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006813840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006813072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407006810576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007649872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007651792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007653712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007653520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007654096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007651984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007655440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007656016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007653904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007655824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407007662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014973712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014974864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014974672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014974288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014975440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014973904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014975248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014973520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014976400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014975824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014976208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014976784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014976976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014977168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014974480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014978320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014978128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014978896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014979472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2407014977936: TensorSpec(shape=(), dtype=tf.resource, name=None)
